# %%
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import json

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Gene Expression Data

# %%
h5_filtered = '../data/CytAssist_11mm_FFPE_Human_Lung_Cancer_filtered_feature_bc_matrix.h5'

# %%
adata =  sc.read_10x_h5(h5_filtered)
# Out:
# /opt/homebrew/anaconda3/envs/bio/lib/python3.11/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/homebrew/anaconda3/envs/bio/lib/python3.11/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata.var_names_make_unique()

# %%
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 6195 × 18085
#     var: 'gene_ids', 'feature_types', 'genome'

# %%
# cell barcodes
adata.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [AACAATCCGAGTGGAC-1, AACAATGGAACCACAT-1, AACACCAGCCTACTCG-1, AACACCATTCGCATAC-1, AACACCGAGCTTGGAT-1, AACACCTAAGCATTGC-1, AACACGCAGATAACAA-1, AACACTCGAAGTATCA-1, AACACTCGTGAGCTTC-1, AACAGGAATTCTGTGA-1, AACAGGATACTCTTAG-1, AACAGGCCAGGCCGCT-1, AACAGGCCATCCGCGT-1, AACAGGCCATTGTCAC-1, AACAGTATCAACGCTT-1, AACAGTATCCGCCTGG-1, AACAGTCAATGTGATA-1, AACAGTCTGGTTGATG-1, AACAGTGATGTACATC-1, AACATACTAGCCGAAG-1, AACATACTCCACAGTT-1, AACATACTCCAGCTGA-1, AACATAGAAGGTGAGT-1, AACATAGGAGGCGTCC-1, AACATAGGTCCATAGC-1, AACATAGGTTCCGCAC-1, AACATAGTCGCAGCTC-1, AACATATGCACTTCTA-1, AACATCAACATCTTGA-1, AACATCAAGGCTGGCT-1, AACATGACCGTACGGA-1, AACATGACGCCTGGAC-1, AACATGCACTTCGGAT-1, AACCAACAATCGGTAC-1, AACCAAGACCAACTGA-1, AACCAAGCGTATACCG-1, AACCAAGCTAGATACG-1, AACCAAGGCGTTATGT-1, AACCAAGTGACCGAAG-1, AACCAATCAGTTCCTC-1, AACCAATCCGATCGCT-1, AACCATAAGCTCGACT-1, AACCATACCATAGACG-1, AACCGAAGTAGCCTGC-1, AACCGCCTAGCTGTCA-1, AACCGTTCAAGGTCAG-1, AACCGTTGTAGAGCTC-1, AACCTACCGGTAACGC-1, AACCTATGACCTGCTC-1, AACCTCCGTAATTCTG-1, AACCTGTCCTGCGAGC-1, AACCTTACCAGCTTAC-1, AACCTTCAAGGAAGTT-1, AACCTTCTGCCTACTG-1, AACGAACAAGGCCGAG-1, AACGACCAATAACTCA-1, AACGACCGCTTGCGGT-1, AACGACGGAGATTAAT-1, AACGAGAATGAATTAT-1, AACGAGCTACGACACC-1, AACGAGCTGTAATATT-1, AACGAGGAATCTAGAA-1, AACGAGGACATATTAA-1, AACGAGTCACATCTGG-1, AACGCACGTAACATGC-1, AACGCAGGAGCAGACG-1, AACGCATACAAGGCGA-1, AACGCATATGATACCT-1, AACGCTCAGGAGTCAG-1, AACGCTCAGGCCAGCT-1, AACGCTCGTGGTCGAC-1, AACGCTGTCCTGGATC-1, AACGGAATCGTATTGA-1, AACGGCAATTGTGGTC-1, AACGGCACCACTGTAA-1, AACGGCCGTACTTCCT-1, AACGGCGACGTCCACC-1, AACGGCGAGGAAGGTT-1, AACGGCGAGTGCCGAG-1, AACGGTCGTATTAGGC-1, AACGTAAGACGGTTAG-1, AACGTCATGGACTCAC-1, AACGTGAAGTAACTGG-1, AACGTTAGGAGCGTTG-1, AACGTTAGTCACAACT-1, AACTAGCACGTTGCAT-1, AACTAGGCACAGGCTG-1, AACTAGTAATGAGCCA-1, AACTAGTCGTCCGGCT-1, AACTATAACAATAACC-1, AACTATCTTACCGAGT-1, AACTATCTTCGGTGGC-1, AACTATGCCACGGTAC-1, AACTATGTCAGTTAAG-1, AACTCAACTAATAGGT-1, AACTCATGAGGAACGC-1, AACTCATGATCCAACG-1, AACTGAAGTGGATGGT-1, AACTGCAAGCAACGGA-1, AACTGCCGATGAACTT-1, ...]
#
# [6195 rows x 0 columns]

# %%
# gene variable data
adata.var.head()
# Out:
#                 gene_ids    feature_types  genome
# SAMD11   ENSG00000187634  Gene Expression  GRCh38
# NOC2L    ENSG00000188976  Gene Expression  GRCh38
# KLHL17   ENSG00000187961  Gene Expression  GRCh38
# PLEKHN1  ENSG00000187583  Gene Expression  GRCh38
# PERM1    ENSG00000187642  Gene Expression  GRCh38

# %%
# gene expression matrix: gene expression values across all genes for cell at index 10
adata.X[10, :].toarray()
# Out:
# array([[  2.,   8.,   2., ..., 174.,  70., 772.]], dtype=float32)

# %% [markdown]
# ## Spatial Data

# %%
# spatial coordinate information of cells
spatial_data = '../data/spatial/tissue_positions.csv'

# coordinates scaling information
scaling_data = '../data/spatial/scalefactors_json.json'

# %%
with open(scaling_data) as f:
    scaling_factors = json.load(f)
    
scaling_factors
# Out:
# {'regist_target_img_scalef': 0.15580368,
#  'tissue_hires_scalef': 0.051934563,
#  'tissue_lowres_scalef': 0.015580369,
#  'fiducial_diameter_fullres': 383.59472791732895,
#  'spot_diameter_fullres': 219.1969873813308}

# %%
spatial_df = pd.read_csv(spatial_data)

# rename 10x Genomics column names for convenience
spatial_df.columns = ['barcode', 'in_tissue', 'x', 'y', 'image_x', 'image_y']

# multiply image_x, image_y coordinates by scaling factor
spatial_df['image_x'] = spatial_df['image_x'] * scaling_factors['tissue_hires_scalef']
spatial_df['image_y'] = spatial_df['image_y'] * scaling_factors['tissue_hires_scalef']

print(f'spatial_df shape: {spatial_df.shape}')

# select spots only in tissue
spatial_df = spatial_df[spatial_df['in_tissue'] == 1].reset_index(drop=True)
print(f'in_tissue only spatial_df shape: {spatial_df.shape}')
# Out:
# spatial_df shape: (14336, 6)
# in_tissue only spatial_df shape: (6195, 6)

# %%
spatial_df.head()
# Out:
#               barcode  in_tissue   x   y      image_x     image_y
# 0  TGAGCTCCGTTGCTTC-1          1  10  32  1583.173218  353.155028
# 1  CTAAGTTCGGACGGCT-1          1  10  34  1583.380957  372.111144
# 2  GCCTTCGCTCAACCTG-1          1  10  36  1583.536760  391.119194
# 3  TGGTACTGCACTGTCG-1          1  10  38  1583.692564  410.075309
# 4  ATTAGTATCTATGAAG-1          1  11  13  1565.203860  173.045964

# %% [markdown]
# ## Merge Gene Expression & Spatial Data
#
# The adata object has its data in separated sections We will use the spatial data barcode as a key to build a coherent dataset.

# %%
tissue_img = plt.imread('../data/spatial/tissue_hires_image.png')
tissue_img.shape
# Out:
# (1708, 2000, 3)

# %%
# add values from spatial_df 'x' column to adata that has matching 'barcode' index
adata.obs['x'] = spatial_df.set_index('barcode').loc[adata.obs_names, 'image_x']
adata.obs['y'] = spatial_df.set_index('barcode').loc[adata.obs_names, 'image_y']

adata.obs.head()
# Out:
#                               x            y
# AACAATCCGAGTGGAC-1    58.374449   509.478063
# AACAATGGAACCACAT-1   861.075055   359.802652
# AACACCAGCCTACTCG-1  1239.262542   422.747343
# AACACCATTCGCATAC-1   886.938467  1374.655948
# AACACCGAGCTTGGAT-1   827.577261   284.237863

# %% [markdown]
# ## View Tissue Spots

# %%
# visualize tissue image
plt.figure(figsize=(10, 10))
plt.imshow(tissue_img)

# plot tissue spots
# NOTE: we flipped coordinates to match traditional cartesian system
# 10x has y-coordinates in top left, and x-coordinates start in bottom left
plt.scatter(adata.obs['y'], adata.obs['x'], s=7, c='cyan', alpha=0.4, edgecolors='black')

plt.title('Spatial Transcriptomics - Cell Positions')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')

plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Quality Control Metrics

# %%
# qc metrics will be calculated and added to adata object
sc.pp.calculate_qc_metrics(adata, inplace=True)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 6195 × 18085
#     obs: 'x', 'y', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %%
adata.obs.head()
# Out:
#                               x            y  n_genes_by_counts  \
# AACAATCCGAGTGGAC-1    58.374449   509.478063              11981
# AACAATGGAACCACAT-1   861.075055   359.802652               9371
# AACACCAGCCTACTCG-1  1239.262542   422.747343               9567
# AACACCATTCGCATAC-1   886.938467  1374.655948              11195
# AACACCGAGCTTGGAT-1   827.577261   284.237863               9977
#
#                     log1p_n_genes_by_counts  total_counts  log1p_total_counts  \
# AACAATCCGAGTGGAC-1                 9.391161      115467.0           11.656749
# AACAATGGAACCACAT-1                 9.145482       47607.0           10.770756
# AACACCAGCCTACTCG-1                 9.166179       60219.0           11.005760
# AACACCATTCGCATAC-1                 9.323312      101700.0           11.529793
# AACACCGAGCTTGGAT-1                 9.208138       62929.0           11.049778
#
#                     pct_counts_in_top_50_genes  pct_counts_in_top_100_genes  \
# AACAATCCGAGTGGAC-1                   28.299861                    31.936397
# AACAATGGAACCACAT-1                   28.888609                    32.291470
# AACACCAGCCTACTCG-1                   29.963965                    33.658812
# AACACCATTCGCATAC-1                   31.485742                    35.090462
# AACACCGAGCTTGGAT-1                   28.956443                    32.530312
#
#                     pct_counts_in_top_200_genes  pct_counts_in_top_500_genes
# AACAATCCGAGTGGAC-1                    36.186963                    44.106108
# AACAATGGAACCACAT-1                    36.650072                    44.913563
# AACACCAGCCTACTCG-1                    38.069380                    46.566698
# AACACCATTCGCATAC-1                    39.164208                    46.945919
# AACACCGAGCTTGGAT-1                    36.827218                    45.049182

# %%
adata.var.head()
# Out:
#                 gene_ids    feature_types  genome  n_cells_by_counts  \
# SAMD11   ENSG00000187634  Gene Expression  GRCh38               2531
# NOC2L    ENSG00000188976  Gene Expression  GRCh38               5472
# KLHL17   ENSG00000187961  Gene Expression  GRCh38               1766
# PLEKHN1  ENSG00000187583  Gene Expression  GRCh38                616
# PERM1    ENSG00000187642  Gene Expression  GRCh38                568
#
#          mean_counts  log1p_mean_counts  pct_dropout_by_counts  total_counts  \
# SAMD11      0.622276           0.483830              59.144471        3855.0
# NOC2L       2.863761           1.351641              11.670702       17741.0
# KLHL17      0.356578           0.304965              71.493140        2209.0
# PLEKHN1     0.105892           0.100652              90.056497         656.0
# PERM1       0.096207           0.091856              90.831316         596.0
#
#          log1p_total_counts
# SAMD11             8.257385
# NOC2L              9.783690
# KLHL17             7.700748
# PLEKHN1            6.487684
# PERM1              6.391917

# %%
# plot distribution of expressed gene counts per cell
sc.pl.violin(adata, ['n_genes_by_counts'], jitter=0.4, xlabel='density', ylabel='number of expressed genes in a single cell')

# %%
sc.pl.violin(adata, ['total_counts'], jitter=0.4, xlabel='density', ylabel='total RNA counts')
